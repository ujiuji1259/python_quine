##########################################################################################################
##########################################################################################################
'''

# %%
# https://lazesoftware.com/ja/tool/hugeaagen/

# %%
aaraw = aaraw_1 + aaraw_2 + aaraw_3 + aaraw_4 + aaraw_5 + aaraw_6 + aaraw_7 + aaraw_8 + aaraw_9

# %%
len(aaraw_1),len(aaraw_2),len(aaraw_3),len(aaraw_4), len(aaraw_5), len(aaraw_6), len(aaraw_7), len(aaraw_8), len(aaraw_9)
# Out:
# (3103, 3103, 3103, 3103, 3103, 3103, 3103, 3103, 3104)

# %%
import re

def create_ascii(v):
    chrs = "^(~:"
    aa = v.replace(" ","0").replace("`","0").replace(".","0").replace("\"","0").replace("]","0").replace("!","0").replace("?","0").replace("_","0")
    for c in chrs:
        aa = aa.replace(c,"0")
    # 開業文字以外の文字列を0に置換
    aa = re.sub(r"[^0\n`]","1",aa)
    return aa
aa = create_ascii(aaraw)
aa_1 = create_ascii(aaraw_1)

# %%
print(aa)
# Out:
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 1111111100000000001111111111111111111111111111000000000011111111111111111111111111110000001111111111111111
# 1111111100000000001111111111111111111111111111000000000011111111111111111111111111000000001111111111111111
# 1111111100000000000011111111111111111111111111000000000011111111111111111111110000000000001111111111111111
# 1111111100000000000011111111111111111111111100000000000011111111111111111111000000000000001111111111111111
# 1111111100000000000011111111111111111111111100000000000011111111111111111100000000110000001111111111111111
# 1111111100000011000000111111111111111111110000001100000011111111111111110000000011110000001111111111111111
# 1111111100000011000000111111111111111111110000001100000011111111111111111100111111110000001111111111111111
# ...

# %%
import base64
import zlib
def decode_base64_and_inflate( b64string ):
    decoded_data = base64.b64decode( b64string )
    return zlib.decompress( decoded_data , -15).decode()

def deflate_and_base64_encode( string_val ):
    zlibbed_str = zlib.compress( string_val )
    compressed_string = zlibbed_str[2:-4]
    return base64.b64encode( compressed_string )

# %%
encodedaa = deflate_and_base64_encode(aa.encode()).decode()
encodedaa_1 = deflate_and_base64_encode(aa_1.encode()).decode()

# %%
len(aa), len(encodedaa), len(encodedaa) / len(aa)
# Out:
# (27928, 1344, 0.04812374677742767)

# %%
len(encodedaa_1)
# Out:
# 164

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());
exec(s:=m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".re
place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;
import~~base64~~as~~b6;
import~~zlib;
import~~random;
from~~datetime~~import~~datetime;
random.seed(datetime.now().timestamp());
tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);
lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x)); 
di=zlib.decompress(b6.b64decode(\"'''+encodedaa+'''\"),-15).decode();
r=random.randint(0,8);
dii=di[r*'''+str(len(aaraw_1))+''':(r+1)*'''+str(len(aaraw_1))+'''];
ss=s.replace(chr(32),"~"+"~")+"#"*sum(lme(dii));
print("".join([tr(c=="1",ss[sum(lme(dii)[:j])],tr(c=="0","@"+"@",c))for(j,c)in(enumerate(dii))]).replace("@"+"@",chr(32)));
'''))
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
# )),globa          ls());exec(s:=m(\'\'%r\'\'))          """%s;import~~base64~~a              s~~b6;import~
# ~zlib;im          port~~random;from~~datetime~          ~import~~datetime;r                      andom.see
# d(dateti            me.now().timestamp());tr=l          ambda~~x,y,z:~~(y          ~~if~~          x~~else
# ~~z);lme            =lambda~~x:list(map(lamb            da~~x:tr(x=="1",1      ,0),x));di=zli      b.decom
# press(b6            .b64decode("7ZtRcuQgDET/            cxr2/pdLpSobg1B        LArew8VhfCWp44        MFTLT
# P++rcsvi      5A      lb+w5COqBSikUFCRYZDG      Gm      UI5WlKWYQ6MiEUk      vmKegrJqJ92qUxD9Uo      HZV8g
# nL87Spfa      WS      LKm8gOqJH/XhRIH//jzH      6o      9ovIH4iAwlPYE4V      cwjNQsYEGUPnxojZE6      berDK
# ...

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~random;from~~datetim
e~~impor          t~~datetime;random.seed(date          time.now().timestamp());                tr=lambda~
~x,y,z:~          ~(y~~if~~x~~else~~z);lme=lam          bda~~x:list(map(lamb                    da~~x:tr(x
=="1",1,            0),x));di=zlib.decompress(          b6.b64decode("7ZtR            ktwgDET/cxpy/8ulUpWs
QaglgVuM            8aCvXdTwhAdcdDHz6/ey+PVu            VPkJSz6iWoBCCgUV        GQZprFGGUJ6mlEWoKxNCIZmvqE
tIRv1tl8            o0VK90UPYDwvmno3SpnSWivE            J2QI38d1Agff2PM/      uh2heRPxABhUvYE4VOCe9AxQYaQO
XHQR2Uhd      Lf      DDKwqohIQklMaAt7ME0j      e6      JxCPZA66ONRDU9      vdZAcc7sX41i2IMnou47EV2TaA8WoH
RQwpkdgd      JQ      WoaMsnJUe2DPl4jylgvN      iX      ggmj3wQSRUBESx      B8WMp6Lkg7iNyo+DOigLpS3PPiwVXu
ZUlL+rSH      ci      sq+zhSMopLHmSUZZaoji      nd      m/FsWyB8tQ2uIh      OpHSRZsn2gMLk4oKPsA79kBi01E1bg
FKKlMuKp      6LGn      UiBBQuIQZaiLr+J9      oDvc      wUlBZ1P8qdiI      9pUPlxUAdlofAirSOm0rdJ4hfBAqhxJx
LT0O0B1n      wOdf      fMbmmoqCvzNNS8Pa      jbU1      FtaxA150Tath      uoSCFL          UJEWypk9MsvdUHiR
BFFxe1Dc      eBIq6k      SIKFyCFZrmGaio    PdgTFR      lmCJUfB3VQFk      p/                  M8hAqv7N5+6r
OZQOkir6      nQgJhT      T+0/gsau7Mfl      CNXO9o      5T+AspcVxYkU              NSZR          kawHS/kimP
4o024Pel      j6nciT      UHF7sBcq6kSI      KFxCBE      RG2S/nECpqD6          QKlZh6J9L2S7        sTkb1ef7
o9qH1Q1j      K9wlfhRU      9F2fuLeC      fijUC7qP      DLJKMwiHZ74I        O+BrWJE7n+1kYgOh      FtC0+gIt
l6eA1GRm      mtJmr0zI      4+nTSUBH      0A9T9DsQ      cI1WZSUaEHWL      f4A5NQsYF1WCJqal/h      AewZ9H7k
UhDvRIoS      dZ56J2KB      Xn+6Pah9      UGiJtgFV      2qYSYg7KBv2T      c5xIAJT6442qywKUNa        vZM7s/
p9eghDDx      dyLrUJ2M+D      sREs      orxAd9HjV6      ZgeghSjRmIFS      55RzUQEEfBSYU8adCEzz      70SWoY
wk+ytTy1      BwSQRRA4Wb      E375      6fag9kHpbw      YZrqo0kYYqal      ioCSeipTopzx5ozSko      vblpZZ3Z
Ube9UeOf      FS7Qyyuflmhh      Op    F26A7NdSKliy      rJtgcQxEaNz2      ryzD7zWU2h0KOwVuAU      Ck21amfZ
g01Qg06E      gcIlPAvVdOfZ            g14sWvgoGT+C      DCcCnvzLT7cHtQ      9KfzPIcFRgmbNR5v      YFqCkn0i
bsLRxBGZ      q+sRNyUHo3Gz            V5ZkedmvYvQU      3Zgw1QE06EiXIK        KQVVR0f1sFKF        hbphD1pE
EkrCOmni      70SCqGF78GGUEC        b+TmQYhUsIgRag      lI7sO5G2xqaZhSpK        CAnLiTiY        BpUfL0X9AQ
=="),-15      ).decode();r=r        andom.randint(      0,8);dii=di[r*3210                    :(r+1)*3210]
;ss=s.re      place(chr(32),      "~"+"~")+"#"*sum      (lme(dii));print("".                join([tr(c=="1
",ss[sum(lme(dii)[:j])],tr(c=="0","@"+"@",c))for(j,c)in(enumerate(dii))]).replace("@"+"@",chr(32)));'''))#
##########################################################################################################
##########################################################################################################
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
# )),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~random;from~~datetim
# e~~impor          t~~datetime;random.seed(date          time.now().timestamp());tr=lam      bda~~x,y,z:~~(
# y~~if~~x          ~~else~~z);lme=lambda~~x:lis          t(map(lambda~~x:tr(x=="1",1,        0),x));di=zlib
# .decompr            ess(b6.b64decode("7ZtRktwg          DET/cxpy/8ulUpWsQaglgVuM8a          CvXdTwhAdcdDHz
# 6/ey+PVu            VPkJSz6iWoBCCgUVGQZprFGG            UJ6mlEWoKxNCIZmvqEtIRv1t            l8o0VK90UPYDwv
# mno3SpnS            WivEJ2QI38d1Agff2PM/uh2h            eRPxABhUvYE4VOCe9AxQYaQO            XHQR2UhdLfDDKw
# qohIQklM      aA      t7ME0je6JxCPZA66ONRD      U9      vdZAcc7sX41i2IMnou47EV      2T      aA8WoHRQwpkdgd
# ...

# %%
exec("""import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))""".replace("_",chr(32)),globals());
exec(s:=m('''s="""exec(\\"\\"\\"import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))\\"\\"\\".re
place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;
import~~base64~~as~~b6;
import~~zlib;
import~~random;
from~~datetime~~import~~datetime;
random.seed(datetime.now().timestamp());
tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);
lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x)); 
di=zlib.decompress(b6.b64decode(\"'''+encodedaa+'''\"),-15).decode();
r=random.randint(0,8);
dii=di[r*'''+str(len(aaraw_1))+''':(r+1)*'''+str(len(aaraw_1))+'''];
ss=re.sub(chr(32),"~"+"~",s)+"#"*sum(lme(dii));
t="".join([tr(c=="1",ss[sum(lme(dii)[:j])],tr(c=="0","@"+"@",c))for(j,c)in(enumerate(dii))]);
print(re.sub("@{2}",chr(32),t));
'''))
# Out:
# exec("""import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))""".replace("_",chr(32)),globals());
# exec(s:=m('''s="""exec(\\"\\"\\"import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))\\"\\"\\".re
# place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~rand
# om;from~          ~datetime~~import~~datetime;          random.seed(dat                              etime
# .now().t          imestamp());tr=lambda~~x,y,z          :~~(y~~if~~x~                                  ~el
# se~~z);l            me=lambda~~x:list(map(lamb          da~~x:tr(x=="                                1",1,
# 0),x));d            i=zlib.decompress(b6.b64            decode("7ZtRktwgDET/cxpy/8ulUpWsQaglgVu      M8aCv
# XdTwhAdc            dDHz6/ey+PVuVPkJSz6iWoBC            CgUVGQZprFGGUJ6mlEWoKxNCIZmvqEtIRv1tl        8o0VK
# 90UPYDwv      mn      o3SpnSWivEJ2QI38d1Ag      ff      2PM/uh2heRPxABhUvYE4VOCe9AxQYaQOXHQR2      UhdLfDD
# ...

# %%
exec("""import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))""".replace("_",chr(32)),globals());
exec(s:=m('''s="""exec(\\"\\"\\"import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))\\"\\"\\".re
place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~rand
om;from~          ~datetime~~import~~datetime;          random.seed(dat                              etime
.now().t          imestamp());tr=lambda~~x,y,z          :~~(y~~if~~x~                                  ~el
se~~z);l            me=lambda~~x:list(map(lamb          da~~x:tr(x=="                                1",1,
0),x));d            i=zlib.decompress(b6.b64            decode("7ZtRktwgDET/cxpy/8ulUpWsQaglgVu      M8aCv
XdTwhAdc            dDHz6/ey+PVuVPkJSz6iWoBC            CgUVGQZprFGGUJ6mlEWoKxNCIZmvqEtIRv1tl        8o0VK
90UPYDwv      mn      o3SpnSWivEJ2QI38d1Ag      ff      2PM/uh2heRPxABhUvYE4VOCe9AxQYaQOXHQR2      UhdLfDD
KwqohIQk      lM      aAt7ME0je6JxCPZA66ON      RD      U9vdZAcc7sX41i2IMnou47EV2TaA8WoHRQwpk      dgdJQWo
aMsnJUe2      DP      l4jylgvNiXggmj3wQSRU      BE      SxB8WMp6Lkg7iNyo+DOigLpS3PPiwVXuZUl      L+rSHcisq
+zhSMopL      HmSU      ZZaojindm/FsWyB8      tQ2u      IhOpHSRZsn2gMLk4oKPsA79kBi01E1bgFKK      lMuKp6LGn
UiBBQuIQ      ZaiL      r+J9oDvcwUlBZ1P8      qdiI      9pUPlxUAdlofAirSOm0rdJ4hfBAqhxJxL      T0O0B1nwOdf
fMbmmoqC      vzNNS8      PajbU1FtaxA150    Tathuo      SCFLUJEWypk9MsvdUHiRBFFxe1DceBIq6      kSIKFyCFZrm
GaioPdgT      FRlmCJ      UfB3VQFkp/M8      hAqv7N      5+6rOZQOkir6nQgJhTT+0/gsau7MflC      NXO9o5T+AspcV
xYkUNSZR      kawHS/      kimP4o024Pel      j6nciT      UHF7sBcq6kSIKFxCBERG2S/nECpqD6Q      KlZh6J9L2S7sT
kb1ef7o9      qH1Q1jK9      wlfhRU9F      2fuLeCfi      jUC7qPDLJKMwiHZ74IO+BrWJE7n+1        kYgOhFtC0+gIt
l6eA1GRm      mtJmr0zI      4+nTSUBH      0A9T9DsQ      cI1WZSUaEHWLf4A5NQsYF1WCJqal/      hAewZ9H7kUhDvRI
oSdZ56J2      KBXn+6Pa      h9UGiJtg      FV2qYSYg      7KBv2Tc5xIAJT6442qywKUNavZM        7s/p9eghDDxdyLr
UJ2M+DsR      EsorxAd9Hj      V6Zg      eghSjRmIFS      55RzUQEEfBSYU8adCEzz70SWoYw      k+ytTy1BwSQRRA4Wb
E3756fag      9kHpbwYZrq      o0kY      YqalioCSei      pTopzx5ozSkovblpZZ3ZUbe9U        eOfFS7QyyuflmhhOp
F26A7NdS      KliyrJtgcQxE      aN    z2ryzD7zWU2h      0KOwVuAUCk21amfZg01Qg06Eg      cIlPAvVdOfZg14sWvgo
GT+CDCcC      nvzLT7cHtQ9K            fzPIcFRgmbNR      5vYFqCkn0ibsLRxBGZq+sRNyU      Ho3GzV5ZkedmvYvQU3Z
gw1QE06E      iXIKKQVVR0f1            sFKFhbphD1pE      EkrCOmni70SCqGF78GGUECb      +TmQYhUsIgRaglI7sO5G2
xqaZhSpK      CAnLiTiYBpUfL0        X9AQ=="),-15).      decode();r=random.randi      nt(0,8);dii=di[r*3210
:(r+1)*3      210];ss=re.sub        (chr(32),"~"+"      ~",s)+"#"*sum(lme(dii        ));t="".join([tr(c=="
1",ss[su      m(lme(dii)[:j]      )],tr(c=="0","@"      +"@",c))for(j,c)in(en      umerate(dii))]);print(r
e.sub("@{2}",chr(32),t));'''))############################################################################
##########################################################################################################
##########################################################################################################
# Out:
# exec("""import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))""".replace("_",chr(32)),globals());
# exec(s:=m('''s="""exec(\\"\\"\\"import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))\\"\\"\\".re
# place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~rand
# om;from~          ~datetime~~import~~datetime;          random.seed(datetime.            now().timestamp()
# );tr=lam          bda~~x,y,z:~~(y~~if~~x~~else          ~~z);lme=lambda~~                    x:list(map(la
# mbda~~x:            tr(x=="1",1,0),x));di=zlib          .decompress(b6.          b64d          ecode("7ZtR
# ktwgDET/            cxpy/8ulUpWsQaglgVuM8aCv            XdTwhAdcdDHz6/e      y+PVuVPkJSz6        iWoBCCgUV
# GQZprFGG            UJ6mlEWoKxNCIZmvqEtIRv1t            l8o0VK90UPYDw      vmno3SpnSWivEJ2Q      I38d1Agff
# 2PM/uh2h      eR      PxABhUvYE4VOCe9AxQYa      QO      XHQR2UhdLfDDK      wqohIQklMaAt7ME0je      6JxCPZA
# ...

# %%
exec("""import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))""".replace("_",chr(32)),globals());
exec(s:=m('''s="""exec(\\"\\"\\"import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))\\"\\"\\".re
place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~rand
om;from~          ~datetime~~import~~datetime;          random.seed(datetime.            now().timestamp()
);tr=lam          bda~~x,y,z:~~(y~~if~~x~~else          ~~z);lme=lambda~~                    x:list(map(la
mbda~~x:            tr(x=="1",1,0),x));di=zlib          .decompress(b6.          b64d          ecode("7ZtR
ktwgDET/            cxpy/8ulUpWsQaglgVuM8aCv            XdTwhAdcdDHz6/e      y+PVuVPkJSz6        iWoBCCgUV
GQZprFGG            UJ6mlEWoKxNCIZmvqEtIRv1t            l8o0VK90UPYDw      vmno3SpnSWivEJ2Q      I38d1Agff
2PM/uh2h      eR      PxABhUvYE4VOCe9AxQYa      QO      XHQR2UhdLfDDK      wqohIQklMaAt7ME0je      6JxCPZA
66ONRDU9      vd      ZAcc7sX41i2IMnou47EV      2T      aA8WoHRQwpkdg      dJQWoaMsnJUe2DPl4j      ylgvNiX
ggmj3wQS      RU      BESxB8WMp6Lkg7iNyo+D      Oi      gLpS3PPiwVXuZ      UlL+rSHcisq+zhSMop      LHmSUZZ
aojindm/      FsWy      B8tQ2uIhOpHSRZsn      2gML      k4oKPsA79kBi0      1E1bgFKKlMuKp6LGnU      iBBQuIQ
ZaiLr+J9      oDvc      wUlBZ1P8qdiI9pUP      lxUA      dlofAirSOm0rd      J4hfBAqhxJxLT0O0B1      nwOdffM
bmmoqCvz      NNS8Pa      jbU1FtaxA150Ta    thuoSC      FLUJEWypk9Msv      dUHiRBFFxe1DceBIq6      kSIKFyC
FZrmGaio      PdgTFR      lmCJUfB3VQFk      p/M8hA      qv7N5+6rOZQOk        ir6nQgJhTT+0/g        sau7Mfl
CNXO9o5T      +AspcV      xYkUNSZRkawH      S/kimP      4o024Pelj6nciTU        HF7sBcq6            kSIKFxC
BERG2S/n      ECpqD6QK      lZh6J9L2      S7sTkb1e      f7o9qH1Q1jK9wlfhR                  U9      F2fuLeC
fijUC7qP      DLJKMwiH      Z74IO+Br      WJE7n+1k      YgOhFtC0+gItl6eA1GR              mmtJ      mr0zI4+
nTSUBH0A      9T9DsQcI      1WZSUaEH      WLf4A5NQ      sYF1WCJqal/hAewZ9H7kUhDvRIoSdZ56J2KBX      n+6Pah9
UGiJtgFV      2qYSYg7KBv      2Tc5      xIAJT6442q      ywKUNavZM7s/p9eghDDxdyLrUJ2M+DsREsorx      Ad9HjV6
ZgeghSjR      mIFS55RzUQ      EEfB      SYU8adCEzz      70SWoYwk+ytTy1BwSQRRA4WbE3756fag9kH      pbwYZrqo0
kYYqalio      CSeipTopzx5o      zS    kovblpZZ3ZUb      e9UeOfFS7QyyuflmhhOpF26A7NdSKliyrJt      gcQxEaNz2
ryzD7zWU      2h0KOwVuAUCk            21amfZg01Qg0      6EgcIlPAvVdOfZg14sWvgoGT+CDCcCnvz        LT7cHtQ9K
fzPIcFRg      mbNR5vYFqCkn            0ibsLRxBGZq+      sRNyUHo3GzV5ZkedmvYvQU3Zgw1QE06        EiXIKKQVVR0
f1sFKFhb      phD1pEEkrCOmni        70SCqGF78GGUEC      b+TmQYhUsIgRaglI7sO5G2xqaZh          SpKCAnLiTiYBp
UfL0X9AQ      =="),-15).deco        de();r=random.      randint(0,8);di                    i=di[r*3210:(r+
1)*3210]      ;ss=re.sub(chr      (32),"~"+"~",s)+      "#"*sum(lme(dii                ));t="".join([tr(c=
="1",ss[sum(lme(dii)[:j])],tr(c=="0","@"+"@",c))for(j,c)in(enumerate(dii))]);print(re.sub("@{2}",chr(32),t
));'''))##################################################################################################
##########################################################################################################
# Out:
# exec("""import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))""".replace("_",chr(32)),globals());
# exec(s:=m('''s="""exec(\\"\\"\\"import_re;m=lambda_x:re.sub("~{2}",chr(32),"".join(x.split()))\\"\\"\\".re
# place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~rand
# om;from~          ~datetime~~import~~datetime;          random.seed(datetime.now().t      imestamp());tr=l
# ambda~~x          ,y,z:~~(y~~if~~x~~else~~z);l          me=lambda~~x:list(map(lamb        da~~x:tr(x=="1",
# 1,0),x))            ;di=zlib.decompress(b6.b64          decode("7ZtRktwgDET/cx            py/8ulUpWsQaglgV
# uM8aCvXd            TwhAdcdDHz6/ey+PVuVPkJSz            6iWoBCCgUVGQZprFGGUJ              6mlEWoKxNCIZmvqE
# tIRv1tl8            o0VK90UPYDwvmno3SpnSWivE            J2QI38d1Agff2PM/uh        2h      eRPxABhUvYE4VOCe
# 9AxQYaQO      XH      QR2UhdLfDDKwqohIQklM      aA      t7ME0je6JxCPZA66        ONRD      U9vdZAcc7sX41i2I
# ...
