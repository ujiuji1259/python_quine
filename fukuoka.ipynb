# %%
aas = [
    r'''
##########################################################################################################
##########################################################################################################
##########################################################################################################
##########################################################################################################
########          ############################          ##################                ################
########          ############################          ##############                        ############
########            ##########################          ############            ####            ##########
########            ########################            ############      ##############        ##########
########            ########################            ##################################      ##########
########      ##      ####################      ##      ##################################      ##########
########      ##      ####################      ##      ##################################      ##########
########      ##      ####################      ##      ##################################      ##########
########      ####      ################      ####      ##################################      ##########
########      ####      ################      ####      ##############################        ############
########      ######      ##############    ######      ##################                  ##############
########      ######      ############      ######      ##################              ##################
########      ######      ############      ######      ##################                    ############
########      ########      ########      ########      ##############################          ##########
########      ########      ########      ########      ##################################        ########
########      ########      ########      ########      ####################################      ########
########      ##########      ####      ##########      ####################################      ########
########      ##########      ####      ##########      ####################################      ########
########      ############      ##    ############      ####################################      ########
########      ############            ############      ##################################        ########
########      ############            ############      ##################################      ##########
########      ##############        ##############      ##########        ############          ##########
########      ##############        ##############      ##########                            ############
########      ##############      ################      ############                      ################
##########################################################################################################
##########################################################################################################''',
    r'''
##########################################################################################################
##########################################################################################################
##########################################################################################################
##########################################################################################################
############    ##########################################################################################
############    ######                                #######                                          ###
############    ######                                #######                                          ###
############    #############################################    ##################################    ###
####                  ####                      #############    ######    ############      ######    ###
####                  ####                      #############    ########    ##########    ########    ###
##################    ####    ##############    #############    ########      ######      ########    ###
################    ######    ##############    #############    ##########  ########    ##########    ###
##############      ######    ##############    #############    ##                              ##    ###
##############    ########                      #############    ##                              ##    ###
############    ##########                      #############    ##############    ################    ###
##########        ###########################################    ##############    ################    ###
########            ####                            #########    ######  ######    ########  ######    ###
######          ##    ##                            #########    ######  ######    ########  ######    ###
####      ##    ####        ########    ########    #########    ######  ######    ########  ######    ###
####    ####    ########    ########    ########    #########    ######  ######    ########  ######    ###
############    ########                            #########    ######  ######    ########  ######    ###
############    ########                            #########    ######                      ######    ###
############    ########    ########    ########    #########    ######                      ######    ###
############    ########    ########    ########    #########    ######  ##########################    ###
############    ########    ########    ########    #########    ######  ##########################    ###
############    ########                            #########    ##################################    ###
############    ########                            #########    ########################              ###
############    ########    ####################    #########    ########################              ###
##########################################################################################################
##########################################################################################################''',
    r'''
##########################################################################################################
##########################################################################################################
##########################################################################################################
###############################################################  #########################################
#############    ################    ##########################  #########################################
#######            ##############    ##########################  ######                                ###
###            ####                              ##############  ######                                ###
###          ######                              ##############  ################    #####################
#########    ########                          ################  ################    #####################
#########    ########                          ########                ##########        #################
#                  ##############    ##################                ##########        #################
#                                                  ##########    ####################                #####
#########    ######                                ##########    ########          ##                #####
#########    ################################################    ########          ##    ########    #####
#######      ##########                        ############        ######    ##    ##    ##  ####    #####
#######        ########                        ############          ####  ####    ##    ##    ##    #####
#####            ######    ################    ############            ##  ####    ##    ####      #######
#####        ##    ####                        ##########    ##  ##    ##  ####    ##    ######    #######
#####  ##    ####  ####                        ##########    ##  ########    ##    ##    ######      #####
###    ##    ##########                        ########    ####  ########          ##    ####        #####
#      ##    ##########                        ########    ####  ########  ##########    ####    ##    ###
#    ####    ##########    ################    ########  ######  ########  ##########    ##    ####    ###
#########    ##########                        ################  ##############              #############
#########    ##########                        ################  ##############          #################
#########    ##############    ########  ######################  #########################################
#########    ############      ######          ################  ######                                  #
#########    ########        ############        ##############  ######                                  #
#########    ######      ####################    ##############  #########################################
##########################################################################################################
##########################################################################################################''',
    r'''
##########################################################################################################
##########################################################################################################
##########################################################################################################
#############  ###########################################################################################
###########    ############################    ###########################################################
###########    ##################                ##############                                      #####
###########    ######                      ####################                                      #####
###########    ######              ############################    ##############    ############    #####
###########    ################    ##########    ##############    ##############    ############    #####
#####                ##    ####    ##########    ##############    ##############    ############    #####
#####                ##    ######    ######    ################    ##############    ############    #####
###########    ########    ######    ######    ################                                      #####
###########    ##########    ####    ####    ##################                                      #####
###########    ##########    ############    ##################    ##############    ############    #####
###########    ####################  ##########################    ##############    ############    #####
###########          ############    ##########################    ##############    ############    #####
###########          ############    ##########################    ##############    ############    #####
#####            ####                              ############    ##############    ############    #####
#####          ######                              ############                                      #####
#####    ##    ##################      ########################                                      #####
###########    ################          ######################    ##############    ############    #####
###########    ##############        ##    ####################    ##############    ############    #####
###########    ############    ##    ####    ##################    ##############    ############    #####
###########    ##########      ##    ######    ################    ##############    ############    #####
###########    ########      ####    ########      ##########      ##############    ############    #####
###########    ####      ########    ##########    ##########    ################    ############    #####
#####          ######  ##########    ########################    ################    ####            #####
#####          ##################    ######################    ############################          #####
#############################################################  ###########################################
##########################################################################################################
'''
]

# %%
# https://lazesoftware.com/ja/tool/hugeaagen/

# %%
aaraw = ''.join(aas)

# %%
[len(aa) for aa in aas]
# Out:
# [3210, 3210, 3210, 3211]

# %%
import re

def create_ascii(v):
    chrs = "^(~:"
    aa = v.replace(" ","0").replace("`","0").replace(".","0").replace("\"","0").replace("]","0").replace("!","0").replace("?","0").replace("_","0")
    for c in chrs:
        aa = aa.replace(c,"0")
    # 開業文字以外の文字列を0に置換
    aa = re.sub(r"[^0\n`]","1",aa)
    return aa
aa = create_ascii(aaraw)

# %%
print(aa)
# Out:
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111
# 1111111100000000001111111111111111111111111111000000000011111111111111111100000000000000001111111111111111
# 1111111100000000001111111111111111111111111111000000000011111111111111000000000000000000000000111111111111
# 1111111100000000000011111111111111111111111111000000000011111111111100000000000011110000000000001111111111
# 1111111100000000000011111111111111111111111100000000000011111111111100000011111111111111000000001111111111
# 1111111100000000000011111111111111111111111100000000000011111111111111111111111111111111110000001111111111
# ...

# %%
import base64
import zlib
def decode_base64_and_inflate( b64string ):
    decoded_data = base64.b64decode( b64string )
    return zlib.decompress( decoded_data , -15).decode()

def deflate_and_base64_encode( string_val ):
    zlibbed_str = zlib.compress( string_val )
    compressed_string = zlibbed_str[2:-4]
    return base64.b64encode( compressed_string )

# %%
encodedaa = deflate_and_base64_encode(aa.encode()).decode()

# %%
len(encodedaa)
# Out:
# 892

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());
exec(s:=m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".re
place("_",chr(32)),globals());exec(s:=m(\'\'%r\'\'))"""%s;
import~~base64~~as~~b6;
import~~zlib;
import~~re;
from~~datetime~~import~~datetime;
tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);
lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x)); 
di=zlib.decompress(b6.b64decode(\"'''+encodedaa+'''\"),-15).decode();
r=0;
rr=re.search(";r=(\d);rr=",s);
r=(int(rr.group(1))+1)if(int(rr.group(1))+1<'''+ str(len(aas)) +''')else(0);
dii=di[r*'''+str(len(aas[0]))+''':(r+1)*'''+str(len(aas[0]))+'''];
ss=s.replace(chr(32),"~"+"~").replace("r=0;rr","r=%s;rr"%r)+"#"*sum(lme(dii));
print("".join([tr(c=="1",ss[sum(lme(dii)[:j])],tr(c=="0","@"+"@",c))for(j,c)in(enumerate(dii))]).replace("@"+"@",chr(32)));
'''))
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
# )),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
# mport~~datetime;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x))
# ;di=zlib.dec    ompress(b6.b64decode("7ZZdcsMwCITfc5r4/pdrO9PUAnYX9Oe0U/PQqQTig5Xk6HFcZo8btQj1/DEVrqKezjah
# PAZFAZSC4Ri/    FufqQr                                EY1edil                                          Iqm
# KFxhNeJGPVFI    zf82FD                                o8AMUPL                                          /e2
# 6U+z/iIqKySi    on8bqihgzwgbgm1CtbgLUD6SoNTh/sso+yHiCRaieAk10    IWocyxQ+EvG9o6VuQWFrF1XQB1HNptjDGq    /3a
# gbla                  FqX4                      HFKHUtm4KyMLP    g/aii1    Ra0KFy17AfJ4      D3Otwr    lYc
# ...

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
mport~~datetime;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x))
;di=zlib.dec    ompress(b6.b64decode("7ZZdcsMwCITfc5r4/pdrO9PUAnYX9Oe0U/PQqQTig5Xk6HFcZo8btQj1/DEVrqKezjah
PAZFAZSC4Ri/    FufqQr                                EY1edil                                          Iqm
KFxhNeJGPVFI    zf82FD                                o8AMUPL                                          /e2
6U+z/iIqKySi    on8bqihgzwgbgm1CtbgLUD6SoNTh/sso+yHiCRaieAk10    IWocyxQ+EvG9o6VuQWFrF1XQB1HNptjDGq    /3a
gbla                  FqX4                      HFKHUtm4KyMLP    g/aii1    Ra0KFy17AfJ4      D3Otwr    lYc
ADDn                  uLwh                      6aED8VGYprkqC    +RrJDhwI    S5yis9Kk4R    1lsYa9GU    LHv
EkrPIBRMpm0M5SvXmo    TEaI    PRvbIvnHwDJlAW    EqVk/w+iVMqFK    JZyy14tQ      PHACqp      LwAtRB7V    fhu
rYK2XbUWFJSUAWM4    Haazfq    /6A6frQtCh1efU    0HUPCGdqDUjW/    ulceki1agK  ssyAWOME    7D6AWQCbkT    xEl
hRn6hcIlTlIlRm      uVhwBR    JwDNX6y6i6KVSI    sVeYSxA78rvSQ    l5                              /B    So/
gwj1SsmABhWTIT    k5yvdw4p                      s1FuWDVFcngKN    Me                              S9    UC+
lFsb1yfT2O6K    6gbGF+57w2                      3yjvHkf5jl0TD    zftg1uzKA9A4pr    M7ApnXSFAXGdc+1A    +Un
6YkGAZShhH        tbXlXTEVmpX6pzGiR98WBEW0Bp0PCrjdbtRfRfW/LgZ    R7IhX/dOocBWll    1xfjhILkkImUUoV3    Ccc
ZwLauTxx            iooN                            vwIuRJGH1    jgqBvW  gpo5FO    8JSbkGxM  ZvtFtA    Go9
lpVNNw          Us    Dv                            R/ktLGzyP    Mr3V0H  l5lD6O    CsBu1BMD  PkwJmt    Q3w
XUiW      Gw    RSgL        4fJOo2I/    TOBJ1Lk/    eBaPu1E2Q    Uyuehq  4VzpdB    UUOuzrSP  Qc9+gN    q1L
rehV    c+pD    8A"),-15    ).decode    ();r=1;r    r=re.sear    ch(";r  =(\\d)    ;rr=",s)  ;r=(in    t(r
r.group(1))+    1)if(int                            (rr.group    (1))+1  <4)els    e(0);dii  =di[r*    321
0:(r+1)*3210    ];ss=s.r                            eplace(ch    r(32),                      "~"+"~    ").
replace("r=1    ;rr","r=    %s;rr"%r    )+"#"*su    m(lme(dii    ));pri                      nt("".    joi
n([tr(c=="1"    ,ss[sum(    lme(dii)    [:j])],t    r(c=="0",    "@"+"  @",c))for(j,c)in(enumerate(    dii
))]).replace    ("@"+"@"    ,chr(32)    ));'''))    #########    ######  ##########################    ###
############    ########                            #########    ##################################    ###
############    ########                            #########    ########################              ###
############    ########    ####################    #########    ########################              ###
##########################################################################################################
##########################################################################################################
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
# )),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
# mport~~datetime;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lamb  da~~x:list(map(lambda~~x:tr(x=="1",1,0),x
# ));di=zlib.de    compress(b6.b64d    ecode("7ZZdcsMwCITfc5r4/pd  rO9PUAnYX9Oe0U/PQqQTig5Xk6HFcZo8btQj1/DEV
# rqKezja            hPAZFAZSC4Ri/F    ufqQrEY1edilIqmKFxhNeJGPVF  Izf82F                                Do8
# AMU            PL/e                              26U+z/iIqKySio  n8bqih                                gzw
# gbg          m1Ctbg                              LUD6SoNTh/sso+  yHiCRaieAk10IWoc    yxQ+EvG9o6VuQWFrF1XQB
# 1HNptjDGq    /3agblaF                          qX4HFKHUtm4KyMLP  g/aii1Ra0KFy17Af    J4D3OtwrlYcADDnuLwh6a
# ...

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
mport~~datetime;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lamb  da~~x:list(map(lambda~~x:tr(x=="1",1,0),x
));di=zlib.de    compress(b6.b64d    ecode("7ZZdcsMwCITfc5r4/pd  rO9PUAnYX9Oe0U/PQqQTig5Xk6HFcZo8btQj1/DEV
rqKezja            hPAZFAZSC4Ri/F    ufqQrEY1edilIqmKFxhNeJGPVF  Izf82F                                Do8
AMU            PL/e                              26U+z/iIqKySio  n8bqih                                gzw
gbg          m1Ctbg                              LUD6SoNTh/sso+  yHiCRaieAk10IWoc    yxQ+EvG9o6VuQWFrF1XQB
1HNptjDGq    /3agblaF                          qX4HFKHUtm4KyMLP  g/aii1Ra0KFy17Af    J4D3OtwrlYcADDnuLwh6a
ED8VGYprk    qC+RrJDh                          wIS5yis9                Kk4R1lsYa9        GULHvEkrPIBRMpm0M
5                  SvXmoTEaIPRvbI    vnHwDJlAWEqVk/w+iV                MqFKJZyy14        tQPHACqpLwAtRB7Vf
h                                                  urYK2XbUWF    JSUAWM4Haazfq/6A6frQ                tCh1e
fU0HUPCGd    qDUjW/                                ulceki1agK    ssyAWOME          7D                6AWQC
bkTxElhRn    6hcIlTlIlRmuVhwBRJwDNX6y6i6KVSIsVeYSxA78rvSQl5/B    So/gwj1S          sm    ABhWTITk    5yvdw
4ps1FuW      DVFcngKNMe                        S9UC+lFsb1yf        T2O6K6    gb    GF    +5  7w23    yjvHk
f5jl0TD        zftg1uzK                        A9A4prM7ApnX          SFAX  Gdc+    1A    +U    n6    YkGAZ
ShhHt            bXlXTE    VmpX6pzGiR98WBEW    0Bp0PCrjdbtR            fR  fW/L    gZ    R7Ih      X/dOocB
Wll1x        fj    hILk                        kImUUoV3Cc    cZ  wL    au  Txxi    oo    NvwIuR    JGH1jgq
BvWgp  o5    FO8J  SbkG                        xMZvtFtAGo    9l  pVNNwUsD    vR    /k    tLGzyP      Mr3V0
Hl5    lD    6OCsBu1BMD                        PkwJmtQ3    wXUi  WGwRSgL4          fJ    Oo2I        /TOBJ
1      Lk    /eBaPu1E2Q                        Uyuehq4V    zpdB  UUOuzrSP  Qc9+gNq1Lr    ehVc    +p    D8A
"    ),-1    5).decode(    );r=2;rr=re.sear    ch(";r=(  \\d);r  r=",s);r  =(int(rr.g    ro    up(1    ))+
1)if(int(    rr.group(1                        ))+1<4)else(0);d  ii=di[r*3210:(              r+1)*3210];ss
=s.replac    e(chr(32),                        "~"+"~").replace  ("r=2;rr","r=%          s;rr"%r)+"#"*sum(
lme(dii))    ;print("".join    ([tr(c==  "1",ss[sum(lme(dii)[:j  ])],tr(c=="0","@"+"@",c))for(j,c)in(enume
rate(dii)    )]).replace(      "@"+"          @",chr(32)));''')  )#####                                  #
#########    ########        ############        ##############  ######                                  #
#########    ######      ####################    ##############  #########################################
##########################################################################################################
##########################################################################################################
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
# )),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
# mport~~dateti  me;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x
# ));di=zlib.    decompress(b6.b64decode("7ZZ    dcsMwCITfc5r4/pdrO9PUAnYX9Oe0U/PQqQTig5Xk6HFcZo8btQj1/DEVrq
# KezjahPAZFA    ZSC4Ri/FufqQrEY1ed                ilIqmKFxhNeJGP                                      VFIzf
# 82FDo8AMUPL    /e26U+                      z/iIqKySion8bqihgzwg                                      bgm1C
# tbgLUD6SoNT    h/sso+              yHiCRaieAk10IWocyxQ+EvG9o6Vu    QWFrF1XQB1HNpt    jDGq/3agblaF    qX4HF
# KHUtm4KyMLP    g/aii1Ra0KFy17Af    J4D3OtwrlY    cADDnuLwh6aED8    VGYprkqC+RrJDh    wIS5yis9Kk4R    1lsYa
# ...

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("  ~"+"~",chr(32))\\"\\"\\".replace("_",chr(
32)),globals(    ));exec(s:=m(\'\    \\'%r\'\'))"""%s;import~~b  ase64~~as~~b6;import~~zlib;import~~re;fro
m~~date            time~~import~~    datetime;tr=lambda~~x,y,z:  ~~(y~~                                if~
~x~            ~els                              e~~z);lme=lamb  da~~x:                                lis
t(m          ap(lam                              bda~~x:tr(x=="  1",1,0),x));di=z    lib.decompress(b6.b64
decode("7    ZZdcsMwC                          ITfc5r4/pdrO1PXA  nYX9Oe00/DQqQzig    xV29Dhus8cLUM8fU+Eq6u
lsE8pjUBR    AKRiO8Xt                          xri4Ui1F                9LkapaIrCF        VYj3qgnCqn5X4ZCww
N                  QfHi5t01/mfUXU    VkhERX921BFAXtW2BB                sE6rF3YDyk        QSlhvsvo+yHiCdYiO
I                                                  l1EA3oq61Q    OEvGTs7VuYWFLJ2XwF1H                NnTHG
NQ++2NWom    qvS+LU                                WqAm4KyMLP    h9aii1Ta          0K                Fy17A
fJ4D3Otwr    lYcADhr1FYQ9NiC9VDMU1SVBfK9mhQwGJcxRW+lKcoyy2cFY    jqNh3CaW          fI    BRMpm0M5    SvXmo
TE6IDRe      2XvAvkBTKA                        sJErJ/h9EqZQ        LUSzll    rN    ag    OK  BFVS    XgDei
Dmq/DNV        xVsq2o8K                        WkoAsZgK1194          oZB0  /bxa    Fj    lk    P9    AAKzn
IHSr0            bzQR6T    LppBaqyLRMwxjgBq    58KJuBGFC+BF            fW  JyiV    CV    S5CZ      ZaLBXcg
AcdQr        b+    Mqpt                        ChRj7CnMJY    kf  +V    Fr  I+Ve    g8    hlEqDM    lAxpUTI
bk5Cj  fw    4Vv9  liUD                        1JdXQCOMuW    dq  BbSi2Jn5    fp    6H    NFdQdn      C/Ml5
bb5    R3    j2O8h27Jh7                        usQ9uzaI    8AIl  rMrNXOOs          KA    eI+4        9qH8p
H      yw    4QEy1DCOKq                        tLe+KqdD    s1D+  NET16tyA  oojXofFDA7    fYfU    P2    /w4
M    oNgx    V/zQqDK30k    kHnKLEhKWQSpVTBf    cJ1JqB9l  idOUbH  hM+BGFLm  SjKNiUA9qa    iz    aFZZ    yC4
qt2dNuAW0    wejqNahpOC                        vj9KH+EhUOeR/n+K  qjcHEqPsxKwC8X              EkFdIsgf1XUBd
GAZbhLIQL    u80KvbDBJ5                        EXeeDn+J1N8omiMl  VTwPvlU5XQZFhV          yPdM+jRH1Cj1nUvvP
Mi/QE="),    -15).decode();    r=2;rr=r  e.search(";r=(\\d);rr=  ",s);r=(int(rr.group(1))+1)if(int(rr.grou
p(1))+1<4    )else(0);dii      =di[r*          2996:(r+1)*2996]  ;ss=s.                                  r
eplace(ch    r(32),"~        "+"~").repla        ce("r=2;rr","r  =%s;rr                                  "
# %r)+"#"*s    um(lme      (dii));print("".join    ([tr(c=="1",ss  [sum(lme(dii)[:j])],tr(c=="0","@"+"@",c))
for(j,c)in(enumerate(dii))]).replace("@"+"@",chr(32)));'''))##############################################
##########################################################################################################
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('\''s="""ex  ec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr
# (32)),globa    ls());exec(s:=m(\'\\\\\'%r\'    \'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;fr
# om~~datetim    e~~import~~datetim                e;tr=lambda~~x                                      ,y,z:
# ~~(y~~if~~x    ~~else                      ~~z);lme=lambda~~x:l                                      ist(m
# ap(lambda~~    x:tr(x              =="1",1,0),x));di=zlib.decom    press(b6.b64de    code("7ZZdcs    MwCIT
# fc5r4/pdrO1    PXAnYX9Oe00/DQqQ    zigxV29Dhu    s8cLUM8fU+Eq6u    lsE8pjUBRAKRiO    8Xtxri4Ui1F9    Lkapa
# IrCFV                Yj    3qgn    Cqn5X4ZCww    NQfHi5t01/mfUX    UVkhERX921BFAX    tW2BBsE6rF3Y    DykQS
# lhvsv                o+    yHiCdY    iOIl1E    A3oq61QOEvGTs7Vu    YWFLJ2XwF1HNnT    HGNQ++2NWomq    vS+LU
# ...

# %%
exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
)),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
mport~~dateti  me;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x
));di=zlib.    decompress(b6.b64decode("7ZZ    dcsMwCITfc5r4/pdrO9PUAnYX9Oe0U/PQqQTig5Xk6HFcZo8btQj1/DEVrq
KezjahPAZFA    ZSC4Ri/FufqQrEY1ed                ilIqmKFxhNeJGP                                      VFIzf
82FDo8AMUPL    /e26U+                      z/iIqKySion8bqihgzwg                                      bgm1C
tbgLUD6SoNT    h/sso+              yHiCRaieAk10IWocyxQ+EvG9o6Vu    QWFrF1XQB1HNpt    jDGq/3agblaF    qX4HF
KHUtm4KyMLP    g/aii1Ra0KFy17Af    J4D3OtwrlY    cADDnuLwh6aED8    VGYprkqC+RrJDh    wIS5yis9Kk4R    1lsYa
9GULH                vE    krPI    BRMpm0M5Sv    XmoTEaIPRvbIvn    HwDJlAWEqVk/w+    iVMqFKJZyy14    tQPHA
CqpLw                At    RB7Vfh    urYK2X    bUWFJSUAWM4Haazf    q/6A6frQtCh1ef    U0HUPCGdqDUj    W/ulc
eki1agKssyA    WOME7D6A    WQCbkT    xElhRn    6hcIlTlIlRmuVhwB                                      RJwDN
X6y6i6KVSIs    VeYSxA78rv    SQl5    /BSo    /gwj1SsmABhWTITk5y                                      vdw4p
s1FuWDVFcng    KNMeS9UC+l    Fsb1yfT2O6K6    gbGF+57w23yjvHkf5j    l0TDzftg1uzKA9    A4prM7ApnXSF    AXGdc
+1A+Un6YkGA    ZShhHtbXlXTEVmpX6pzG  iR98WBEW0Bp0PCrjdbtRfRfW/L    gZR7IhX/dOocBW    ll1xfjhILkkI    mUUoV
3CccZwLauTx          xiooNvwIuRJG    H1jgqBvWgpo5FO8JSbkGxMZvtF    tAGo9lpVNNwUsD    vR/ktLGzyPMr    3V0Hl
5lD6OCsBu1B          MDPkwJmtQ3wX    UiWGwRSgL4fJOo2I/TOBJ1Lk/e    BaPu1E2QUyuehq    4VzpdBUUOuzr    SPQc9
+gNq1            Lreh                              Vc+pD8A"),-1    5).decode();r=    3;rr=re.sear    ch(";
r=(\\          d);rr=                              ",s);r=(int(                                      rr.gr
oup(1    ))    +1)if(int(rr.group      (1))+1<4)else(0);dii=di[                                      r*321
0:(r+1)*321    0];ss=s.replace(          chr(32),"~"+"~").repla    ce("r=3;rr","r    =%s;rr"%r)+"    #"*su
m(lme(dii))    ;print("".join        ([    tr(c=="1",ss[sum(lme    (dii)[:j])],tr    (c=="0","@"+    "@",c
))for(j,c)i    n(enumerate(    di    i))]    ).replace("@"+"@",    chr(32)));''')    )###########    #####
###########    ##########      ##    ######    ################    ##############    ############    #####
###########    ########      ####    ########      ##########      ##############    ############    #####
###########    ####      ########    ##########    ##########    ################    ############    #####
#####          ######  ##########    ########################    ################    ####            #####
#####          ##################    ######################    ############################          #####
#############################################################  ###########################################
##########################################################################################################
# Out:
# exec("""m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))""".replace("_",chr(32)),globals());exec(s:=
# m('''s="""exec(\\"\\"\\"m=lambda_x:"".join(x.split()).replace("~"+"~",chr(32))\\"\\"\\".replace("_",chr(32
# )),globals());exec(s:=m(\'\'%r\'\'))"""%s;import~~base64~~as~~b6;import~~zlib;import~~re;from~~datetime~~i
# mport~~datetime;tr=lambda~~x,y,z:~~(y~~if~~x~~else~~z);lme=lambda~~x:list(map(lambda~~x:tr(x=="1",1,0),x))
# ;di=zlib          .decompress(b6.b64decode("7Z          ZdcsMwCITfc5r4/pdr                O9PUAnYX9Oe0U/PQ
# qQTig5Xk          6HFcZo8btQj1/DEVrqKezjahPAZF          AZSC4Ri/FufqQr                        EY1edilIqmKF
# xhNeJGPV            FIzf82FDo8AMUPL/e26U+z/iIq          KySion8bqihg            zwgb            gm1CtbgLUD
# 6SoNTh/s            so+yHiCRaieAk10IWocyxQ+E            vG9o6VuQWFrF      1XQB1HNptjDGq/        3agblaFqX4
# HFKHUtm4            KyMLPg/aii1Ra0KFy17AfJ4D            3OtwrlYcADDnuLwh6aED8VGYprkqC+RrJD      hwIS5yis9K
# ...
